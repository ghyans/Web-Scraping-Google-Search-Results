# %%
#Importing Required Libraries
from selenium import webdriver #This is used to automate web browser
from bs4 import BeautifulSoup #This is used to scrap web data
from bs4.element import Tag #We will use this to search ParseTree using Tag
import time #To set delay
import pandas as pd #To convert extracted HTML data into Data Frame and then convert to csv

# %%
#Initiating browser search
driver = webdriver.Firefox(executable_path="C:\\webdrivers\geckodriver.exe") #My personal choice of Browser is Firefox. Chrome can be used by replacing this line with: driver = webdriver.Chrome(executable_path="C:\\webdrivers\geckodriver.exe")
userinput = input("Enter search keywords:") #User based input for Google Search
google_url = "https://www.google.com/search?q=" + userinput +  "&num=" + str(20) #Parsing the URL.
driver.get(google_url)
time.sleep(5) #We delay this process by 5 seconds to imitate this process like a human process
soup = BeautifulSoup(driver.page_source,'lxml') #Initiation of BeautifulSoup to parse html data
result_div = soup.find_all('div', attrs={'class': 'g'})
# Out:
# Enter search keywords:Precily

# %%
#Declaration of array to store data
Search_Result_URL = [] 
Search_Result_Title = []
Search_Result_Description = []
Appended_Record = []

# %%
#Process of extracting data from source HTML
for r in result_div:
    # This will check is the element is present
    try:
        #Link Extraction
        link = r.find('a', href=True)
        
        #Title Extraction
        title = None
        title = r.find('h3')

        if isinstance(title,Tag):
            title = title.get_text()
            
        #Description Extraction
        description = r.find('span', attrs={'class': 'aCOpRe'})

        if isinstance(description, Tag):
            description = description.get_text()

        #Checking if everything is present and append them into respective array
        if link != '' and title != '' and description != '':
            Search_Result_URL.append(link['href'])
            Search_Result_Title.append(title)
            Search_Result_Description.append(description)
    
    #Returns Exception if element not present and loop continuation
    except Exception as e:
        print(e)
        continue

# %%
#Appending the top 10 extracted data into Appended_Record array
for i in range(10):
    Appended_Record.append((1,Search_Result_Title[i],Search_Result_URL[i],Search_Result_Description[i]))
    
#Prints Record in non tabular form
print(Appended_Record)
# Out:
# [(1, 'Precily AI', 'https://precily.com/', 'cognitive tasks. This needs to. Change. See how Precily is bringing. efficiency and automation for.'), (1, 'Precily AI', 'https://precily.com/aura/', 'Precily Icon. Precily AI. Bringing efficiency and. automation to your workflows. © 2021 Precily Inc. All Right Reserved. Arrow Up Icon Back to top. Cookie Icon.'), (1, 'Precily, Inc. | LinkedIn', 'https://in.linkedin.com/company/precily', 'Precily Aura is an AI tool that provides effective, accurate and simplified methods for various big data operations in an organization. Aura is an expert in fields such\xa0...'), (1, 'PRECILY, INC. - Crunchbase Company Profile & Funding', 'https://www.crunchbase.com/organization/precily-private-limited', 'Precily is Artificial Intelligence platform for enterprises that increases efficiency of workforce by providing AI based solutions.'), (1, 'Precily Private Limited jobs on CutShort', 'https://cutshort.io/company/precily-XDhePOEf', '-Precily AI: Automatic summarization, shortening a business document, book with our AI. Create a summary of the major points of the original document. AI can\xa0...'), (1, 'Precily R&D Private Limited jobs on CutShort', 'https://cutshort.io/company/precily-rd-private-limited-gSPGcITj', "Precily AI is a VC funded start-up headquartered in Palo Alto, US and offices here in New Delhi. Precily's technology is disrupting traditional work flows in\xa0..."), (1, 'Business process automation startup Precily gets seed ...', 'https://www.vccircle.com/business-process-automation-startup-precily-gets-seed-funding/', '21-Sep-2020 — Precily, set up by Bharath Rao in 2016, says it combines artificial intelligence with natural language processing (NLP) to provide its solutions to\xa0...'), (1, 'PRECILY PRIVATE LIMITED - Company, directors and contact ...', 'https://www.zaubacorp.com/company/PRECILY-PRIVATE-LIMITED/U74999KA2016PTC096007', 'Precily Private Limited is a Private incorporated on 26 August 2016. It is classified as Non-govt company and is registered at Registrar of Companies, Bangalore.'), (1, 'Precily | Tracxn', 'https://tracxn.com/d/companies/precily.com', 'Precily Editor rating ... Precily provides an AI and NLP-based data analytics platform. It enables teams to analyze structured and unstructured data, create clusters\xa0...'), (1, 'Precily Reviews by 3 Employees | AmbitionBox', 'https://www.ambitionbox.com/reviews/precily-private-limited-reviews', '3 Precily Reviews by current and past employees about ✓salary & benefits ✓work culture ✓skill development ✓career growth ✓job security ✓work-life\xa0...')]

# %%
#Converting Extracted data into Data Frame
df = pd.DataFrame(Appended_Record,columns=['Page_Number','Search_Result_Title','Search_Result_URL','Search_Result_Description'])

# %%
df.index.name = 'Search_Result_Number' #Setting a column name for Index
df.index = df.index + 1 #Changing indexing to Base 1

# %%
df.head()
# Out:
#                       Page_Number  \
# Search_Result_Number
# 1                               1
# 2                               1
# 3                               1
# 4                               1
# 5                               1
#
#                                                     Search_Result_Title  \
# Search_Result_Number
# 1                                                            Precily AI
# 2                                                            Precily AI
# 3                                              Precily, Inc. | LinkedIn
# 4                     PRECILY, INC. - Crunchbase Company Profile & F...
# 5                              Precily Private Limited jobs on CutShort
#
#                                                       Search_Result_URL  \
# Search_Result_Number
# 1                                                  https://precily.com/
# 2                                             https://precily.com/aura/
# 3                               https://in.linkedin.com/company/precily
# 4                     https://www.crunchbase.com/organization/precil...
# 5                          https://cutshort.io/company/precily-XDhePOEf
#
#                                               Search_Result_Description
# Search_Result_Number
# 1                     cognitive tasks. This needs to. Change. See ho...
# 2                     Precily Icon. Precily AI. Bringing efficiency ...
# 3                     Precily Aura is an AI tool that provides effec...
# 4                     Precily is Artificial Intelligence platform fo...
# 5                     -Precily AI: Automatic summarization, shorteni...

# %%
df.tail()
# Out:
#                       Page_Number  \
# Search_Result_Number
# 6                               1
# 7                               1
# 8                               1
# 9                               1
# 10                              1
#
#                                                     Search_Result_Title  \
# Search_Result_Number
# 6                          Precily R&D Private Limited jobs on CutShort
# 7                     Business process automation startup Precily ge...
# 8                     PRECILY PRIVATE LIMITED - Company, directors a...
# 9                                                      Precily | Tracxn
# 10                         Precily Reviews by 3 Employees | AmbitionBox
#
#                                                       Search_Result_URL  \
# Search_Result_Number
# 6                     https://cutshort.io/company/precily-rd-private...
# 7                     https://www.vccircle.com/business-process-auto...
# 8                     https://www.zaubacorp.com/company/PRECILY-PRIV...
# 9                            https://tracxn.com/d/companies/precily.com
# 10                    https://www.ambitionbox.com/reviews/precily-pr...
#
#                                               Search_Result_Description
# Search_Result_Number
# 6                     Precily AI is a VC funded start-up headquarter...
# 7                     21-Sep-2020 — Precily, set up by Bharath Rao i...
# 8                     Precily Private Limited is a Private incorpora...
# 9                     Precily Editor rating ... Precily provides an ...
# 10                    3 Precily Reviews by current and past employee...

# %%
#Data Frame conversion to CSV file and exporting it to specified Path
df.to_csv(r'C:\Users\Welcome\Desktop\precily.csv')
